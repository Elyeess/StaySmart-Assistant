# %%
# !pip install ace_tools
# Out:
# Collecting ace_tools
#   Downloading ace_tools-0.0-py3-none-any.whl.metadata (300 bytes)
# Downloading ace_tools-0.0-py3-none-any.whl (1.1 kB)
# Installing collected packages: ace_tools
# Successfully installed ace_tools-0.0

# %%
# !pip install translatepy
# Out:
# Collecting translatepy
#   Downloading translatepy-2.3-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from translatepy) (2.32.3)
# Collecting safeIO>=1.2 (from translatepy)
#   Downloading safeIO-1.2.tar.gz (8.0 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from translatepy) (4.13.3)
# Collecting pyuseragents (from translatepy)
#   Downloading pyuseragents-1.0.5-py3-none-any.whl.metadata (4.3 kB)
# Collecting inquirer>=2.8.0 (from translatepy)
#   Downloading inquirer-3.4.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting blessed>=1.19.0 (from inquirer>=2.8.0->translatepy)
#   Downloading blessed-1.20.0-py2.py3-none-any.whl.metadata (13 kB)
# Collecting editor>=1.6.0 (from inquirer>=2.8.0->translatepy)
#   Downloading editor-1.6.6-py3-none-any.whl.metadata (2.3 kB)
# Collecting readchar>=4.2.0 (from inquirer>=2.8.0->translatepy)
#   Downloading readchar-4.2.1-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->translatepy) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->translatepy) (4.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->translatepy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->translatepy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->translatepy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->translatepy) (2025.1.31)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.11/dist-packages (from blessed>=1.19.0->inquirer>=2.8.0->translatepy) (0.2.13)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from blessed>=1.19.0->inquirer>=2.8.0->translatepy) (1.17.0)
# Collecting runs (from editor>=1.6.0->inquirer>=2.8.0->translatepy)
#   Downloading runs-1.2.2-py3-none-any.whl.metadata (10 kB)
# Collecting xmod (from editor>=1.6.0->inquirer>=2.8.0->translatepy)
#   Downloading xmod-1.8.1-py3-none-any.whl.metadata (1.8 kB)
# Downloading translatepy-2.3-py3-none-any.whl (814 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 814.4/814.4 kB 18.1 MB/s eta 0:00:00
# Downloading inquirer-3.4.0-py3-none-any.whl (18 kB)
# Downloading pyuseragents-1.0.5-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 2.0 MB/s eta 0:00:00
# Downloading blessed-1.20.0-py2.py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 4.4 MB/s eta 0:00:00
# Downloading editor-1.6.6-py3-none-any.whl (4.0 kB)
# Downloading readchar-4.2.1-py3-none-any.whl (9.3 kB)
# Downloading runs-1.2.2-py3-none-any.whl (7.0 kB)
# Downloading xmod-1.8.1-py3-none-any.whl (4.6 kB)
# Building wheels for collected packages: safeIO
#   Building wheel for safeIO (setup.py) ... done
#   Created wheel for safeIO: filename=safeIO-1.2-py3-none-any.whl size=6731 sha256=f3f0f9fbc128176cf54e7324646f49189aa69a357f6ed9a88f3a477a06c94fa3
#   Stored in directory: /root/.cache/pip/wheels/e2/6e/c7/424e26c9ededcdc554fd01634506d46fd2e027a395f412f38d
# Successfully built safeIO
# Installing collected packages: safeIO, pyuseragents, xmod, readchar, blessed, runs, editor, inquirer, translatepy
# Successfully installed blessed-1.20.0 editor-1.6.6 inquirer-3.4.0 pyuseragents-1.0.5 readchar-4.2.1 runs-1.2.2 safeIO-1.2 translatepy-2.3 xmod-1.8.1

# %%
import pandas as pd

# Charger le fichier traduit
merged_data = pd.read_csv("/content/data_scrapée+lang.csv")

# %%
merged_data.isnull().sum()
# Out:
# listing_id          0
# description         0
# comments            3
# description_lang    0
# comments_lang       0
# dtype: int64

# %%
merged_data.head()
# Out:
#    listing_id                                        description  \
# 0        3109  Lovely Appartment with one bedroom with a Quee...
# 1        3109  Lovely Appartment with one bedroom with a Quee...
# 2        3109  Lovely Appartment with one bedroom with a Quee...
# 3        3109  Lovely Appartment with one bedroom with a Quee...
# 4        5396  NEW SOFA-BED SINCE JUNE 2023, Please disregard...
#
#                                             comments description_lang  \
# 0            Tout s'est bien déroulé. Merci bien. PG               en
# 1  Un petit nid fouiller douillet situé dans  app...               en
# 2  Appartement spacieux, propre,clair, et calme à...               en
# 3  Appartement totalement rénové, en parfait état...               en
# 4  Perfect location!! Nasrine was a delight and m...               en
#
#   comments_lang
# 0            fr
# 1            fr
# 2            fr
# 3            fr
# 4            en

# %%
merged_data = merged_data.dropna()

# %%
merged_data.shape
# Out:
# (9997, 5)

# %% [markdown]
# ## 🌐 Traduction Automatique Multilingue avec `translatepy`
#
# Ce script automatise la **traduction des descriptions et commentaires non anglophones** en anglais, afin de faciliter les étapes de nettoyage, de similarité et de génération.
#
# ---
#
# ### 🔍 Objectif
# Traduire les colonnes `"description"` et `"comments"` d'un DataFrame `merged_data`, tout en :
# - Respectant les codes de langue détectés.
# - Effectuant la traduction par lots pour éviter les blocages.
# - Ajoutant des colonnes traduites au DataFrame.

# %%
import pandas as pd
import time
from translatepy import Translator

translator = Translator()

# Dictionnaire de correction des codes de langue
lang_corrections = {
    "zh-tw": "zh-TW",  # Chinois traditionnel
    "zh-cn": "zh-CN",  # Chinois simplifié
    "iw": "he",        # Hébreu
    "unknown": "auto"  # Détection automatique pour les langues inconnues
}

# Fonction de traduction avec affichage du statut
def batch_translate(text_list, source_lang):
    if not text_list:
        return []

    # Correction du code de langue
    source_lang = lang_corrections.get(source_lang, source_lang)

    translated_texts = []
    for idx, text in enumerate(text_list):
        try:
            result = translator.translate(text, "english", source_lang)
            translated_texts.append(result.result)
            print(f"✅ [{idx + 1}/{len(text_list)}] {source_lang} → en : {text[:50]}... → {result.result[:50]}...")
        except Exception as e:
            print(f"❌ Erreur [{idx + 1}/{len(text_list)}] : {text[:50]}... | Erreur : {e}")
            translated_texts.append(text)  # Conserver le texte original en cas d'erreur
        time.sleep(0.5)  # Pause pour éviter le blocage

    return translated_texts

# Colonnes à traduire
columns_to_translate = ["description", "comments"]

# Taille du batch
batch_size = 10

# Vérification des colonnes dans le dataset
columns_to_translate = [col for col in columns_to_translate if col in merged_data.columns]

# Appliquer la traduction
for col in columns_to_translate:
    lang_col = f"{col}_lang"

    if lang_col in merged_data.columns:  # Vérifier si la colonne de langue existe
        mask = merged_data[lang_col] != "en"  # Filtrer les textes non anglais
        texts_to_translate = merged_data.loc[mask, col].tolist()
        source_langs = merged_data.loc[mask, lang_col].unique().tolist()

        print(f"\n🔹 Traduction de la colonne : {col}")

        translated_texts = []
        for lang in source_langs:
            sub_mask = (merged_data[lang_col] == lang) & mask
            sub_texts = merged_data.loc[sub_mask, col].tolist()

            if sub_texts:
                print(f"\n🟢 Langue détectée : {lang} - {len(sub_texts)} phrases")
                for i in range(0, len(sub_texts), batch_size):
                    print(f"   ⏳ Batch {i + 1}/{len(sub_texts) // batch_size + 1} en cours...")
                    translated_sub_texts = batch_translate(sub_texts[i:i+batch_size], lang)
                    translated_texts.extend(translated_sub_texts)
                    time.sleep(1)

        # Mettre à jour le DataFrame avec les textes traduits
        merged_data.loc[mask, f"{col}_translated"] = translated_texts
# Out:
# 🔹 Traduction de la colonne : description
#
# 🟢 Langue détectée : so - 100 phrases
#    ⏳ Batch 1/11 en cours...
# ✅ [1/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [2/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [3/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [4/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [5/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [6/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [7/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [8/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [9/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [10/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
#    ⏳ Batch 11/11 en cours...
# ✅ [1/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [2/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [3/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [4/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [5/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [6/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [7/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [8/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [9/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [10/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
#    ⏳ Batch 21/11 en cours...
# ✅ [1/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [2/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [3/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [4/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [5/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [6/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [7/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [8/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [9/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [10/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
#    ⏳ Batch 31/11 en cours...
# ✅ [1/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [2/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [3/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [4/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [5/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [6/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [7/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [8/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [9/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [10/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
#    ⏳ Batch 41/11 en cours...
# ✅ [1/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [2/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [3/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [4/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [5/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [6/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [7/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [8/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [9/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [10/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
#    ⏳ Batch 51/11 en cours...
# ✅ [1/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [2/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [3/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [4/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [5/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [6/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [7/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [8/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [9/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [10/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
#    ⏳ Batch 61/11 en cours...
# ✅ [1/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [2/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [3/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [4/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [5/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [6/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [7/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [8/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [9/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [10/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
#    ⏳ Batch 71/11 en cours...
# ✅ [1/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [2/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [3/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [4/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [5/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [6/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [7/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [8/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [9/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [10/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
#    ⏳ Batch 81/11 en cours...
# ✅ [1/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [2/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [3/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [4/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [5/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [6/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [7/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [8/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [9/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [10/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
#    ⏳ Batch 91/11 en cours...
# ✅ [1/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [2/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [3/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [4/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [5/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [6/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [7/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [8/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [9/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
# ✅ [10/10] so → en : MODERN AND STYLISH APARTMENT, COMPLETE RENOVATION ... → Modann and stylish apartment, complete Renovation ...
#
# 🔹 Traduction de la colonne : comments
#
# 🟢 Langue détectée : fr - 1698 phrases
#    ⏳ Batch 1/170 en cours...
# ✅ [1/10] fr → en : Tout s'est bien déroulé. Merci bien. PG... → Everything went well.Thank you very much.PG...
# ✅ [2/10] fr → en : Un petit nid fouiller douillet situé dans  apparte... → A small cozy nest nest located in a resistant apar...
# ✅ [3/10] fr → en : Appartement spacieux, propre,clair, et calme à pro... → Spacious, clean, clear, quiet apartment near Montp...
# ✅ [4/10] fr → en : Appartement totalement rénové, en parfait état. Tr... → Totally renovated apartment, in perfect condition....
# ✅ [5/10] fr → en : Merci à l’hôte pour sa ponctualité à nous accueill... → Thank you to the host for its punctuality to welco...
# ✅ [6/10] fr → en : Nous avons été très bien accueilli à notre arrivée... → We were very well received when we arrived.Excelle...
# ✅ [7/10] fr → en : Appartement 5 sur 5 !... → Apartment 5 of 5!...
# ✅ [8/10] fr → en : J'ai beaucoup apprécié mon séjour. Très bel appart... → I really enjoyed my stay.Very nice apartment, in t...
# ✅ [9/10] fr → en : nous avons passé un très bon séjour dans cet appar... → We had a very good stay in this very nicely decora...
# ✅ [10/10] fr → en : De retour depuis 2 jours et encore sous le charme ... → Back for 2 days and still under the spell of Paris...
#    ⏳ Batch 11/170 en cours...
# ✅ [1/10] fr → en : Tous ceux qui auront la chance de séjourner chez S... → Everyone who will have the chance to stay with Syl...
# ✅ [2/10] fr → en : Appartement très mignon et bien placé en termes de... → Very cute and well placed apartment in terms of RE...
# ✅ [3/10] fr → en : Toujours aussi sympa l'appartement de Laurence. Ac... → Always so nice Laurence's apartment.Welcoming like...
# ✅ [4/10] fr → en : On se sent bien dans l'appartement de Laurence !... → We feel good in Laurence's apartment!...
# ✅ [5/10] fr → en : Toujours aussi agréable de rester dans l'apparteme... → Always as pleasant to stay in Laurence §'s apartme...
# ✅ [6/10] fr → en : une hotesse  super sympa Laurence est simplement g... → A super nice hostess Laurence is just great a very...
# ✅ [7/10] fr → en : Plaisir partagé.....on est Bien dans l'appartement... → Shared pleasure ..... we are good in Laurence's ap...
# ✅ [8/10] fr → en : On se sent chez soi das l'appart de Laurence et je... → We feel at home in Laurence's apartment and I than...
# ✅ [9/10] fr → en : Un appartement chaleureux, confortable, lumineux, ... → A warm, comfortable, bright, quiet apartment, you ...
# ✅ [10/10] fr → en : Chez Laurence...on se sent comme à la maison. Kris... → At Laurence ... We feel at home.Kristina...
#    ⏳ Batch 21/170 en cours...
# ✅ [1/10] fr → en : Chez Laurence...super comme d'habitude.... → At Laurence ... Super as usual....
# <br/> We had a great stay in Paris ...
# ✅ [3/10] fr → en : Appartement conforme et très agréable ! Nous avons... → Compliant and very pleasant apartment!We were made...
# ✅ [4/10] fr → en : super place !!... → Great place !!...
# ✅ [5/10] fr → en : Super appartement, convivial, grand, propre -  acc... → Super apartment, friendly, large, clean - very war...
# ✅ [6/10] fr → en : Super comme toujours !!... → Great as always !!...
# ✅ [7/10] fr → en : Je reviendrai chez Laurence...bien sûr !!!... → I will come back to Laurence ... Of course !!!...
# ✅ [8/10] fr → en : Chez Laurence...c'est un peu comme à la maison...... → At Laurence ... It's a bit like at home ......
# ✅ [9/10] fr → en : Le logement correspondait parfaitement à notre att... → The accommodation corresponded perfectly to our ex...
# ✅ [10/10] fr → en : Toujours aussi facile et agréable chez Laurence.... → Always as easy and pleasant at Laurence....
#    ⏳ Batch 31/170 en cours...
# ✅ [1/10] fr → en : Chouette ...comme toujours...... → Nice ... as always ......
# ✅ [2/10] fr → en : Toujours un plaisir de revenir chez Laurence !... → Always a pleasure to come back to Laurence!...
# ✅ [3/10] fr → en : Toujours aussi agréable l'accueil, l'appartement..... → Always so pleasant welcome, apartment .......
# ✅ [4/10] fr → en : Facile et sympa comme toujours chez Laurence.... → Easy and nice as always at Laurence....
# ✅ [5/10] fr → en : Séjour très agréable comme toujours...... → Very pleasant stay as always ......
# ✅ [6/10] fr → en : On se sent toujours comme à la maison chez Laurenc... → We always feel at home at Laurence ......
# ✅ [7/10] fr → en : Un petit nid douillet bien placé. <br/>Laurence es... → A little cozy nest well placed.<br/> Laurence is c...
# ✅ [8/10] fr → en : Toujours aussi agréable chez Laurence !!... → Always so pleasant at Laurence !!...
# ✅ [9/10] fr → en : Séjour très agréable comme à chaque fois. On se se... → Very pleasant stay as always.We feel good at Laure...
# ✅ [10/10] fr → en : Laurence est une personne agréable, avenante et am... → Laurence is a pleasant, pleasant and friendly pers...
#    ⏳ Batch 41/170 en cours...
# ✅ [1/10] fr → en : Un séjour chez Laurence est chaudement recommandab... → A stay with Laurence is highly recommendable!Its m...
# ✅ [2/10] fr → en : Séjour sympa comme toujours... → Nice stay as always...
# ✅ [3/10] fr → en : Super comme toujours !... → Great as always!...
# ✅ [4/10] fr → en : Encore un super séjour chez Laurence !!... → Another great stay with Laurence !!...
# ✅ [5/10] fr → en : Chouette séjour comme toujours chez Laurence !!... → Nice stay as always with Laurence !!...
# ✅ [6/10] fr → en : C'est toujours cool chez Laurence...même si cette ... → It's always cool at Laurence ... Even if this week...
# ✅ [7/10] fr → en : Avec Laurence tout est facile...et dans son appart... → With Laurence everything is easy ... and in her ap...
# ✅ [8/10] fr → en : Joli appartement dans le 13è<br/>Très bon accueil ... → Nice apartment in the 13th <br/> Very welcome from...
# ✅ [9/10] fr → en : l appartement est un vrai refuge dans paris près d... → The apartment is a real refuge in Paris near the f...
# ✅ [10/10] fr → en : Laurence s'est montrée très attentive à notre bien... → Laurence was very attentive to our well -being dur...
#    ⏳ Batch 51/170 en cours...
# ✅ [1/10] fr → en : Mon conjoint et moi avons passé un très bon moment... → My spouse and I had a great time at Laurence.The a...
# ✅ [2/10] fr → en : Appartement spacieux et déco sympa.... → Spacious apartment and nice decor....
# ✅ [3/10] fr → en : Laurence était très disponible, réactive et accuei... → Laurence was very available, responsive and welcom...
# ✅ [4/10] fr → en : Laurence est délicieuse, très réactive pour nous d... → Laurence is delicious, very responsive to give us ...
# ✅ [5/10] fr → en : Ce séjour chez Laurence fût parfait avec un accuei... → This stay with Laurence was perfect with a very wa...
# ✅ [6/10] fr → en : Cette appart est une pépite ! Laurence très gentil... → This apartment is a nugget!Laurence very kind, the...
# ✅ [7/10] fr → en : Laurence est une personne accueillante. Son appart... → Laurence is a welcoming person.His apartment is de...
# ✅ [8/10] fr → en : Propre, joliment aménagé, confortable et une impre... → Clean, nicely furnished, comfortable and an impres...
# ✅ [9/10] fr → en : Très bon accueil de Laurence qui est une hôte très... → Very welcome from Laurence which is a very pleasan...
# ✅ [10/10] fr → en : Appartement lumineux, très cozy. Bien communiqué. ... → Bright, very cozy apartment.Well communicated.Metr...
#    ⏳ Batch 61/170 en cours...
# ✅ [1/10] fr → en : Laurence a été très avenante et professionnelle. L... → Laurence was very pleasant and professional.The ac...
# ✅ [2/10] fr → en : Appartement moderne, charmant et atypique, situé d... → Modern, charming and atypical apartment, located i...
# ✅ [3/10] fr → en : Merci a david pour son accueil et son intérieur hy... → Thank you to David for his welcome and his super n...
# ✅ [4/10] fr → en : super séjour super endroit merci beaucoup je revie... → great stay super place thank you very much I would...
# ✅ [5/10] fr → en : Séjour très agréable dans ce studio très calme et ... → Very pleasant stay in this very quiet and nicely a...
# ✅ [6/10] fr → en : David est une personne très agréable et sympathiqu... → David is a very pleasant and friendly person who h...
# ✅ [7/10] fr → en : je recommande.<br/>merci à David et Mireille.<br/>... → I recommend. <br/> Thanks to David and Mireille. <...
# ✅ [8/10] fr → en : David est un super hôte et le loft est très agréab... → David is a great host and the loft is very pleasan...
# ✅ [9/10] fr → en : Un petit appart très agréable, propre et bien four... → A very pleasant, clean and well supplied small apa...
# ✅ [10/10] fr → en : Un quartier excentré qui mérite d'être connu. Un t... → An eccentric district that deserves to be known.Ve...
#    ⏳ Batch 71/170 en cours...
# ✅ [1/10] fr → en : J’ai passer un agréable moment chez David je vous ... → I had a good time at David I recommend it!...
# ✅ [2/10] fr → en : S'il est vrai que l'appartement est petit , il est... → If it is true that the apartment is small, it is p...
# ✅ [3/10] fr → en : Excellent accueil. Propre. Proche des transports.... → Excellent welcome.Own.Close to transport....
# ✅ [4/10] fr → en : Séjour très agréable et logement très bien. ... → Very pleasant stay and very good accommodation....
# ✅ [5/10] fr → en : Bel appartement, spacieux, lumineux et au calme. A... → Beautiful apartment, spacious, bright and quiet.A ...
# ✅ [6/10] fr → en : Merci Lena, nous avons passe un excellent sejour c... → Thank you Lena, we have had an excellent stay with...
# ✅ [7/10] fr → en : Idéalement situé à 2 pas de la porte d'Orléans (mé... → Ideally located 2 steps from the Porte d'Orléans (...
# ✅ [8/10] fr → en : Bon rapport qualité-prix. Logement bien situé entr... → Good value for money.Housing well located between ...
# ✅ [9/10] fr → en : Nous avons passé un très agréable séjour chez Léna... → We had a very pleasant stay with Léna's.The apartm...
# ✅ [10/10] fr → en : Je n'ai pas rencontré personnellement Léna lors de... → I did not personally meet Léna during my stay, but...
#    ⏳ Batch 81/170 en cours...
# ✅ [1/10] fr → en : Logement dans quartier calme, transport à proximit... → Accommodation in a quiet area, transport nearby, t...
# ✅ [2/10] fr → en : L'appartement était très bien.  Lena a pris le tem... → The apartment was very good.Lena took the time to ...
# ✅ [3/10] fr → en : Appartement est bien situe, avec une belle vie. Bo... → Apartment is well located, with a good life.Good c...
# ✅ [4/10] fr → en : Logement conforme à la description et à nos attent... → Accommodation in accordance with the description a...
# ✅ [5/10] fr → en : Bonne expérience dans un appartement très agréable... → Good experience in a very pleasant and welcoming a...
# ✅ [6/10] fr → en : Logement conforme a l'annonce, bien situé, proche ... → Housing in accordance with the announcement, well ...
# ✅ [7/10] fr → en : séjour très agréable.  appartement fonctionnel et ... → Very pleasant stay.Functional and properly equippe...
# ✅ [8/10] fr → en : Nous avons été très bien accueillis par Léna qui e... → We were very well received by Léna who is extremel...
# ✅ [9/10] fr → en : L appartement de Léna est très bien situé :rue cal... → Léna's apartment is very well located: quiet but v...
# ✅ [10/10] fr → en : Merci pour votre accueil chère Lena !... → Thank you for your home dear Lena!...
#    ⏳ Batch 91/170 en cours...
# ✅ [1/10] fr → en : Appartement sympa  très calme. Avec deux balcons q... → Nice apartment very quiet.With two balconies that ...
# ✅ [2/10] fr → en : Nous avons séjourné longtemps chez Léna qui nous a... → We stayed with Léna for a long time who made us ve...
# ✅ [3/10] fr → en : logement fonctionnel avec un bon espace de vie et ... → Functional accommodation with a good living space ...
# ✅ [4/10] fr → en : Logement idéalement situé à 2 pas de tous les comm... → Accommodation ideally located 2 steps from all sho...
# ✅ [5/10] fr → en : Lena est super reactive et trouve une solution a t... → Lena is super reactive and finds a solution to all...
# ✅ [6/10] fr → en : Grand appartement tranquille et bien situé. Mais d... → Large quiet and well located apartment.But outdate...
# ✅ [7/10] fr → en : L'appartement est beau, très lumineux, calme, et a... → The apartment is beautiful, very bright, quiet, an...
# ✅ [8/10] fr → en : Notre séjour dans la maison de Léna était super, l... → Our stay in Léna's house was great, the apartment ...
# ✅ [9/10] fr → en : Le logement de Léna est très bien situé avec les f... → Léna's accommodation is very well located with the...
# ✅ [10/10] fr → en : No comments... → No comments...
#    ⏳ Batch 101/170 en cours...
# ✅ [1/10] fr → en : Merci Stéphanie! Un séjour très agréable!  L'appar... → Thank you Stéphanie!A very pleasant stay!The apart...
# ✅ [2/10] fr → en : Appartement avec énormément de charme, très propre... → Apartment with a lot of charm, very clean and func...
# ✅ [3/10] fr → en : Juste parfait. Quartier genial, un des rares dans ... → Just perfect.Genial district, one of the few in Pa...
# ✅ [4/10] fr → en : Merci pour ce mois passé dans un quartier surprena... → Thank you for this month spent in a surprising and...
# ✅ [5/10] fr → en : L'appartement de Stéphanie est exactement comme su... → Stéphanie's apartment is exactly like in the photo...
# ✅ [6/10] fr → en : Conforme aux photos, l'appartement est très agréab... → Compliant with the photos, the apartment is very n...
# ✅ [7/10] fr → en : L'appartement de stephanie est très cosy et confor... → Stephanie's apartment is very cozy and comfortable...
# ✅ [8/10] fr → en : Stéphanie est une hôtesse parfaite : fiable, arran... → Stéphanie is a perfect hostess: reliable, accommod...
# ✅ [9/10] fr → en : Appartement conforme aux photos, Stéphanie vous la... → Apartment consistent with the photos, Stéphanie le...
# ✅ [10/10] fr → en : J'ai passé une dizaine de jours dans l'appartement... → I spent ten days in Stéphanie's apartment. <br/> n...
#    ⏳ Batch 111/170 en cours...
# ✅ [1/10] fr → en : Logement agréable. Les photos parlent d'elles même... → Pleasant accommodation.The photos speak for themse...
# ✅ [2/10] fr → en : Nous avons passé un agréable séjour, l’appartement... → We had a pleasant stay, the apartment perfectly co...
# ✅ [3/10] fr → en : Parfait, conforme à la description, très bien situ... → Perfect, in accordance with the description, very ...
# ✅ [4/10] fr → en : Je conseille fortement l'appartement de Stéphanie,... → I strongly recommend Stéphanie's apartment, well p...
# ✅ [5/10] fr → en : Antoine est très accueillant et amicable ! L'appar... → Antoine is very welcoming and friendly!The apartme...
# ✅ [6/10] fr → en : Séjour très agréable grâce à l'accueil chaleureux ... → Very pleasant stay thanks to the warm welcome from...
# ✅ [7/10] fr → en : Appartement super sympa et chaleureux à deux pas d... → Super nice and warm apartment a stone's throw from...
# ✅ [8/10] fr → en : Merci Antoine! Séjour très agréable. L'endroit est... → Thank you Antoine!Very pleasant stay.The place is ...
# ✅ [9/10] fr → en : Quelques problèmes matériels vite réglés grâce aux... → Some material problems quickly resolved thanks to ...
# ✅ [10/10] fr → en : Antoine était un hôte très sympathique, j'ai beauc... → Antoine was a very friendly host, I really enjoyed...
#    ⏳ Batch 121/170 en cours...
# ✅ [1/10] fr → en : Très bon séjour chez Antoine, l'appartement est sy... → Very good stay with Antoine, the apartment is frie...
# ✅ [2/10] fr → en : Petit séjour agréable dans un beau quartier... → Small pleasant stay in a beautiful neighborhood...
# ✅ [3/10] fr → en : Aliyah et Philippe m'ont réservé un accueil extrêm... → Aliyah and Philippe gave me an extremely warm welc...
# ✅ [4/10] fr → en : L'accueil de Philippe et d'Alihah est toujours aus... → The welcome from Philippe and Alihah is still as w...
# ✅ [5/10] fr → en : Séjour plus qu'agréable grâce à l'accueil chaleure... → More than pleasant stay thanks to the warm welcome...
# ✅ [6/10] fr → en : Un accueil chaleureux de Philippe. Chambre très ag... → A warm welcome from Philippe.Very pleasant and qui...
# ✅ [7/10] fr → en : Un accueil toujours chaleureux pour ce 2e séjour. ... → An always warm welcome for this 2nd stay.A well -p...
# <br/>...
# ✅ [9/10] fr → en : Philippe est un hôte très sympathique et arrangean... → Philippe is a very friendly and accommodating host...
# <br/...
#    ⏳ Batch 131/170 en cours...
# ✅ [1/10] fr → en : Très bon accueil, la chambre est agréable, très bi... → Very welcome, the room is pleasant, very well loca...
# ✅ [2/10] fr → en : Chambre confortable avec tout ce qu'il faut pour p... → Comfortable room with everything you need to have ...
# ✅ [3/10] fr → en : Un bel appartement. Propre, calme, couchage comfor... → A beautiful apartment.Clean, calm, comfortable sle...
# ✅ [4/10] fr → en : Chambre très bien située et calme. Très bon accuei... → Very well located and quiet room.Very warm welcome...
# ✅ [5/10] fr → en : Super accueil, la chambre est très bien équipée, e... → Super welcome, the room is very well equipped, and...
# ✅ [6/10] fr → en : Aliyah et Philippe sont des hôtes extrêmement char... → Aliyah and Philippe are extremely charming hosts w...
# ✅ [7/10] fr → en : Petit logement extrêmement bien placé dont les fen... → Small accommodation extremely well placed whose wi...
# ✅ [8/10] fr → en : Un studio avec tout le confort possible, décoré av... → A studio with all the possible comfort, carefully ...
# ✅ [9/10] fr → en : Accueil très chaleureux et airbnb idéalement situé... → Very warm welcome and airbnb ideally located and q...
# ✅ [10/10] fr → en : Chambre spacieuse, très propre, grand lit très con... → Spacious, very clean room, very comfortable large ...
#    ⏳ Batch 141/170 en cours...
# ✅ [1/10] fr → en : Des hôtes très agréables et sympathiques. Un espac... → Very pleasant and friendly hosts.A calm, clean and...
# ✅ [2/10] fr → en : Appartement extrêmement bien situé, propre et au c... → Extremely well located, clean and quiet apartment....
# ✅ [3/10] fr → en : Appartement agreable, et lumineux. Il y avait peut... → Able, and bright apartment.There may have been the...
# ✅ [4/10] fr → en : L'appartement de Lola est très bien situé, lumineu... → Lola's apartment is very well located, bright and ...
# ✅ [5/10] fr → en : Appartement tres comfortable et pratique. Contact ... → Very comfortable and practical apartment.Easy cont...
# ✅ [6/10] fr → en : Nous avons passé un agréable séjour dans l'apparte... → We had a pleasant stay in Lola's apartment, quiet,...
# ✅ [7/10] fr → en : Nous nous sommes senti comme chez nous dans cet ap... → We felt at home in this bright, quiet and very wel...
# ✅ [8/10] fr → en : Lola est tout à fait charmante, super conciliante ... → Lola is completely charming, super conciliatory an...
# ✅ [9/10] fr → en : L'appartement de Lola est très lumineux et plein d... → Lola's apartment is very bright and full of charm....
# ✅ [10/10] fr → en : Lola a été réactive à ma demande de derrière minut... → Lola was responsive at my request from behind minu...
#    ⏳ Batch 151/170 en cours...
# ✅ [1/10] fr → en : Notre séjour chez Lola a été super! L'appartement ... → Our stay with Lola was great!The apartment is very...
# ✅ [2/10] fr → en : Appartement avec beaucoup de charme, propre, fonct... → Apartment with lots of charm, clean, functional, a...
# ✅ [3/10] fr → en : Très bon séjour chez Lola, qui est une hôte très r... → Very good stay with Lola, which is a very responsi...
# ✅ [4/10] fr → en : Bien que je n'ai pas eu la chance de rencontrer Lo... → Although I did not have the chance to meet Lola in...
# ✅ [5/10] fr → en : Très jolie appartement, super quartier et une hôte... → Very nice apartment, great neighborhood and a very...
# ✅ [6/10] fr → en : J'ai eu le meilleur temps à Paris et l'appartement... → I had the best time in Paris and Lola's apartment ...
# ✅ [7/10] fr → en : Appartement très bien situé et très bien aménagé. ... → Apartment very well located and very well appointe...
# ✅ [8/10] fr → en : Appartement charmant, chaleureux, très "habité", d... → Charming apartment, warm, very "inhabited", in a d...
# ✅ [9/10] fr → en : Nous avons adoré notre séjour chez Lola! L'apparte... → We loved our stay with Lola!The apartment was very...
# ✅ [10/10] fr → en : Appartement bien distribué, très calme, confortabl... → Well distributed apartment, very quiet, comfortabl...
#    ⏳ Batch 161/170 en cours...
# ✅ [1/10] fr → en : Il s'agit d'un appartement très bien lumineux et a... → It is a very bright and ventilated apartment, loca...
# ✅ [2/10] fr → en : Je n’ai malheureusement pas pu séjourner chez Lola... → Unfortunately, I could not stay with Lola due to c...
# ✅ [3/10] fr → en : Jolie appartement, fonctionnel, calme  et bien sit... → Nice apartment, functional, quiet and well located...
# ✅ [4/10] fr → en : Bien accueilli, elle a toujours essayé d’aider, pr... → Well welcomed, she has always tried to help, held ...
# ✅ [5/10] fr → en : L'appartement de Charlotte est génial, bien situé ... → Charlotte's apartment is great, well located and C...
# ✅ [6/10] fr → en : Appartement facile d'accès et comfortable. L'organ... → Easy to access and comfortable apartment.The organ...
# ✅ [7/10] fr → en : Charlotte a été très accueillante à notre arrivée,... → Charlotte was very welcoming when we arrived, and ...
# ✅ [8/10] fr → en : L'appartement est comme sur les photos<br/>Très ag... → The apartment is like in the photos <br/> very ple...
# ✅ [9/10] fr → en : L'appartement est très agréable, propre et bien si... → The apartment is very nice, clean and well located...
# <br/> I write to you to let you kn...
#    ⏳ Batch 171/170 en cours...
# ✅ [1/10] fr → en : Delphine à répondu très vite à ma demande ce qui n... → Delphine responded very quickly to my request whic...
# ✅ [2/10] fr → en : Delphine est adorable, le quartier on ne peut pas ... → Delphine is adorable, the neighborhood we cannot d...
# ✅ [3/10] fr → en : Logement tres bien situé et agréable.<br/>Merci ... → Housing very well located and pleasant. <br/> Than...
# ✅ [4/10] fr → en : Bien situé ds une rue calme et fenêtres sur cours.... → Well located in a quiet street and window windows....
# ✅ [5/10] fr → en : Espace clair, luminieux, épuré, proper. accessibil... → Clear, bright, refined space, proper.Accessibility...
# ✅ [6/10] fr → en : tres bon accueil, apart  tres bien situé,calme  su... → Very warm welcome, apart very well located, quiet ...
# ✅ [7/10] fr → en : tres petit appartement , silencieux , salle de bai... → very small apartment, silent, rotten bathroom and ...
# ✅ [8/10] fr → en : My daughter and I spent a week in Paris at the beg... → My Daughter and I Spent A Week in Paris at the Beg...
# ✅ [9/10] fr → en : Excelente Location, au plein coeur du Marais, pour... → Excellent rental, in the heart of the marsh, could...
# ✅ [10/10] fr → en : Appartement bien situé. Cependant vieillot et mal ... → Apartment well located.However, old and poorly mai...
#    ⏳ Batch 181/170 en cours...
# ✅ [1/10] fr → en : Très agréable et bien passé... → Very pleasant and well passed...
# ✅ [2/10] fr → en : L'appartement de Benoit est extrêmement bien placé... → Benoit's apartment is extremely well placed: "vill...
# ✅ [3/10] fr → en : L'appartement de Benoit est dans un état de saleté... → Benoit's apartment is in an infamous state of dirt...
# ✅ [4/10] fr → en : j'ai passé un bon séjour de 10 jours chez julie, l... → I had a good 10 -day stay with Julie's, the apartm...
# ✅ [5/10] fr → en : Tout s'est très bien passé chez Julie pour Rémi qu... → Everything went very well at Julie for Rémi who wa...
# ✅ [6/10] fr → en : Accueil très sympathique, bon conseil et apparteme... → Very friendly welcome, good advice and very warm a...
# ✅ [7/10] fr → en : L’appartement de Julie est parfait ! Idéalement si... → Julie's apartment is perfect!Ideally located, brig...
# ✅ [8/10] fr → en : Agréable sejour, tout ce qu'il faut, coin agréable... → Pleasant stay, everything you need, pleasant corne...
# ✅ [9/10] fr → en : Un petit appartement parisien, calme, lumineux, bi... → A small Parisian apartment, quiet, bright, well ap...
# ✅ [10/10] fr → en : Le studio soleil est parfaitement situé dans le qu... → The sun studio is perfectly located in the Marais ...
#    ⏳ Batch 191/170 en cours...
# ✅ [1/10] fr → en : Appartement très  bien situé, propre et confortabl... → Apartment very well located, clean and comfortable...
# ✅ [2/10] fr → en : Nous avons adoré notre séjour d'une semaine dans c... → We loved our week's stay in this apartment.The loc...
# ✅ [3/10] fr → en : Excellent location, comfortable space... → Excellent rental, Comfortable Space...
# ✅ [4/10] fr → en : Sejour merveilleux chez Pascal. Emplacement extrao... → Wonderful stay at Pascal.Extraordinary location, i...
# ✅ [5/10] fr → en : Appartement lumineux et charmant au centre du Mara... → Bright and charming apartment in the center of the...
# ✅ [6/10] fr → en : A 72 ans, nous avons eu plaisir à gravir les 4 éta... → At 72, we enjoyed climbing the 4 floors leading to...
# ✅ [7/10] fr → en : Excellent séjour chez Virginia et Pascal. C'est un... → Excellent stay with Virginia and Pascal.It is a lo...
# ✅ [8/10] fr → en : Petit appartement très bien situé, très confortabl... → Small apartment very well located, very comfortabl...
# ✅ [9/10] fr → en : Bien localisé, tout est à distance de marche. Métr... → Well located, everything is at a distance from wal...
# ✅ [10/10] fr → en : On est immédiatement mis à l'aise dans ce magnifiq... → We are immediately at ease in this magnificent apa...
#    ⏳ Batch 201/170 en cours...
# ✅ [1/10] fr → en : Nous avons passé un excellent séjour à Paris. L'ap... → We had a great stay in Paris.The apartment is supe...
# ✅ [2/10] fr → en : Bonjour,<br/>Nous avons vraiment passé un séjour i... → Hello, <br/> We really had an idyllic stay!<br/> W...
# ✅ [3/10] fr → en : Dès nos premières communications, Sophie était déj... → From our first communications, Sophie was already ...
# ✅ [4/10] fr → en : Un appartement extrêmement agréable (nous étions a... → An extremely pleasant apartment (we were with our ...
# ✅ [5/10] fr → en : Nous avons passé un très bon séjour. L'appartement... → We had a very good stay.The apartment is functiona...
# ✅ [6/10] fr → en : Nous avons vraiment apprécié le logement, il était... → We really appreciated the accommodation, it was ve...
# ✅ [7/10] fr → en : Nous avons passé de très belles vacances dans l’ap... → We had a great vacation in Sophie's apartment, <br...
# ✅ [8/10] fr → en : L'appartement de Sophie est idéalement placé entre... → Sophie's apartment is ideally placed between Belle...
# ✅ [9/10] fr → en : L’appartement de Sophie est très agréable. Le quar... → Sophie’s apartment is very pleasant.The district i...
# ✅ [10/10] fr → en : Fantastic location, worth the price alone! It's sm... → Fantastic rental, Worth the Price Alone!It's small...
#    ⏳ Batch 211/170 en cours...
# ✅ [1/10] fr → en : Appartement trés bien situé, proche du métro et de... → Apartment very well located, close to the metro an...
# ✅ [2/10] fr → en : la chambre est très clean et agréable, c'est calme... → The room is very clean and pleasant, it is quiet (...
# <br/> A few ...
# ✅ [4/10] fr → en : Nous n'avons pas pu nous rencontrer, mais tout s'e... → We could not meet, but everything went well as pla...
# ✅ [5/10] fr → en : L'appartement était parfaitement conforme à la des... → The apartment was perfectly consistent with the de...
# ✅ [6/10] fr → en : Très bon accueil et appart très mignon. Calme et b... → Very welcome and very cute apartment.Quiet and wel...
# ✅ [7/10] fr → en : J'ai passé 3 jours inoubliables dans l'appartement... → I spent 3 unforgettable days in Sonia's apartment;...
# ✅ [8/10] fr → en : Excellent séjour... Hôte très souple sur les horai... → Excellent stay ... very flexible host on schedules...
# ✅ [9/10] fr → en : Appartement trèèèèèèèèèèèès agréable: confort, cla... → Trèèèèèèèèèèèèèèèèèèèèèèèèèèèèèèèèèèèèèèès apartme...
# ✅ [10/10] fr → en : Super séjour ! Très propre, de bon goût, et Sonia ... → Great stay!Very clean, tasteful, and Sonia is alwa...
#    ⏳ Batch 221/170 en cours...
# ✅ [1/10] fr → en : C'est ma première expérience AirBnb et je dois dir... → This is my first Airbnb experience and I must say ...
# ✅ [2/10] fr → en : Très bel appartement , bien équipés, rien à dire<b... → Very nice apartment, well equipped, nothing to say...
# ✅ [3/10] fr → en : Excellent location!... → Excellent rental!...
# ✅ [4/10] fr → en : Comfortable AND convenient!... → Comfortable and convent!...
# ✅ [5/10] fr → en : Appartement propre, bien situé et fonctionnel, nou... → Clean apartment, well located and functional, we h...
# ✅ [6/10] fr → en : Bien situé, beaucoup de placards, bien équipé (seu... → Well located, a lot of cupboards, well equipped (o...
# ✅ [7/10] fr → en : Le logement de Cécile est idéal en tout point de v... → Cécile's accommodation is ideal in every way!Perfe...
# ✅ [8/10] fr → en : Le logement était bien situé et tout était parfait... → The accommodation was well located and everything ...
# ✅ [9/10] fr → en : J'ai ete dans l'appartement de Faina en novembre. ... → I was in the apartment of Faina in November.Her ap...
# ✅ [10/10] fr → en : Le logement de Faina est très bien, propre, foncti... → Faina's accommodation is very good, clean, functio...
#    ⏳ Batch 231/170 en cours...
# ✅ [1/10] fr → en : J'ai été très bien accueilli par une amie de Faina... → I was very well received by a friend from Faina wh...
# ✅ [2/10] fr → en : En fait je n'ai pas rencontré Faina qui était en v... → In fact I did not meet Faina who was traveling ......
# ✅ [3/10] fr → en : Merci tres bon commentaire , appartement propre, b... → Thank you very good comment, clean apartment, good...
# <b...
# ✅ [5/10] fr → en : L'appartement est idéalement situé dans le nord de... → The apartment is ideally located in the north of P...
# ✅ [6/10] fr → en : Tout était parfaitement conforme à la description... → Everything was perfectly in line with the descript...
# ✅ [7/10] fr → en : Séjour très agréable dans un bel appartement paris... → Very pleasant stay in a beautiful very functional ...
# ✅ [8/10] fr → en : Très bon séjour à Paris dans ce petit studio confo... → Very good stay in Paris in this comfortable small ...
# ✅ [9/10] fr → en : Propriétaire très sympas, arrangeante et attention... → Very nice owner, accommodating and attentive to it...
# ✅ [10/10] fr → en : Nous avons passés un très bon séjour dans cet appa... → We had a very good stay in this apartment perfectl...
#    ⏳ Batch 241/170 en cours...
# ✅ [1/10] fr → en : Nous avons été très bien accueillis par Sophie,le ... → We were very well received by Sophie, the accommod...
# ✅ [2/10] fr → en : Super séjour chez Sophie qui est adorable ... → Great stay with Sophie who is adorable...
# ✅ [3/10] fr → en : L'appartement est très bien placé (quartier vivant... → The apartment is very well placed (living neighbor...
# ✅ [4/10] fr → en : Appartement à recommander pour les familles avec e... → Apartment to recommend for families with children....
# ✅ [5/10] fr → en : Première expérience Airbnb et c'était super. Accue... → First Airbnb experience and it was great.Warm welc...
# ✅ [6/10] fr → en : Nous (une famille de quatre personnes) avons eu la... → We (a family of four) had the chance to meet Sophi...
# ✅ [7/10] fr → en : Appart cosy, fidèle à la description, idéalement s... → Cozy apartment, faithful to the description, ideal...
# ✅ [8/10] fr → en : superbe appart. bien placé à 2 pas du metro.<br/>S... → Superb apartment.Well placed 2 steps from the metr...
# ✅ [9/10] fr → en : Nous avons passé une très bonne semaine. L'emplace... → We had a great week.The location of the apartment ...
# ✅ [10/10] fr → en : Un appartement très agréable et accueillant, où no... → A very pleasant and welcoming apartment, where we ...
#    ⏳ Batch 251/170 en cours...
# ✅ [1/10] fr → en : Très bel appartement,  spacieux et idéalement situ... → Very nice apartment, spacious and ideally located....
# ✅ [2/10] fr → en : nice appart, 2min loin de métro, 5 min à coûté du ... → Nice apartment, 2 min away from metro, 5 min cost ...
# ✅ [3/10] fr → en : Merci pour tout Gwenael.<br/>Je recommande vivemen... → Thank you for everything Gwenael. <br/> I highly r...
# ✅ [4/10] fr → en : Studio fonctionnel et agréable, très bien placé, q... → Functional and pleasant studio, very well placed, ...
# ✅ [5/10] fr → en : Nous avons passé un trés agréable séjour grâce à l... → We had a very pleasant stay thanks to Richard's ap...
# ✅ [6/10] fr → en : Excellente situation pour cet appartement plein de... → Excellent situation for this charming apartment.<b...
# ✅ [7/10] fr → en : Je ne peux que confirmer tout ce qu'il y a vait dé... → I can only confirm everything that has already bee...
# ✅ [8/10] fr → en : Best location possible.... → Best rental possible....
# ✅ [9/10] fr → en : Appartement confortable et fonctionnel, très prati... → Comfortable and functional apartment, very practic...
# ✅ [10/10] fr → en : Let others in the Airbnb community know about your... → Let Others in the Airbnb Community Know About Your...
#    ⏳ Batch 261/170 en cours...
# ✅ [1/10] fr → en : Parfait!... → Perfect!...
# ✅ [2/10] fr → en : J'ai eu grand plaisir à occuper l'appartement de J... → I had great pleasure in occupying Jean-François' a...
# ✅ [3/10] fr → en : Il faudrait 6 étoiles pour décrire cet appartement... → It would take 6 stars to describe this charming ap...
# ✅ [4/10] fr → en : Tout s´est bien passé pendant notre journée. L´app... → Everything went well during our day.The apartment ...
# ✅ [5/10] fr → en : Quel endroit agréable, bien situé, bien aménagé et... → What a pleasant place, well located, well appointe...
# ✅ [6/10] fr → en : Un très bon accueil, un appartement très sympas, t... → A very good welcome, a very nice apartment, very w...
# ✅ [7/10] fr → en : Séjour très agréable, l'appartement est lumineux e... → Very pleasant stay, the apartment is bright and pl...
# ✅ [8/10] fr → en : Très bon accueil ; appartement original et chaleur... → Very welcome;Original and warm apartment....
# ✅ [9/10] fr → en : Un lieu inspirant pour écrire.... → An inspiring place to write....
# ✅ [10/10] fr → en : Appartement propre et confortable, près de tous le... → Clean and comfortable apartment, near all services...
#    ⏳ Batch 271/170 en cours...
# ✅ [1/10] fr → en : Merci encore à Guglielmo et Maria pour les accueil... → Thank you again to Guglielmo and Maria for welcomi...
# ✅ [2/10] fr → en : superbe moment parisien.........Marie Odile est un... → Superb Parisian moment ......... Marie Odile is an...
# ✅ [3/10] fr → en : Accueil charmant de Marie-Odile. L'appartement est... → Charming welcome from Marie-Odile.The apartment is...
# ✅ [4/10] fr → en : Appartement très bien placé, à proximité des comme... → Apartment very well placed, close to shops, transp...
# <br/> His apartment is...
# ✅ [6/10] fr → en : Notre séjour chez François et Pascale était parfai... → Our stay with François and Pascale was perfect.Ide...
# ...
# ✅ [2/10] ko → en : 엘레베이터 없는 6층이라 올라가는게 조금 힘들었지만, 정말 좋은 숙소였습니다! 생활에 필요... → It was a little hard to go up because it was the s...
# ✅ [3/10] ko → en : 친구랑 두명이서 5박 했어요. 체크인시간보다 일찍 도착할것같아 말씀드렸더니 제 시간에 맞게... → I had five nights with my friend.I thought I would...
# ✅ [4/10] ko → en : 9일 정도 머물렀습니다. 방도 생각보다 넓었고 근처에 지하철, 마트, 스타벅스, 패스트푸드... → I stayed for 9 days.The room was wider than I thou...
# ✅ [5/10] ko → en : 호스트가 정말 정말 친절하시고<br/>역도 바로앞에있고 주위에 마트랑 패스트 푸드점 많아서... → The host was really kind and it was convenient bec...
# ✅ [6/10] ko → en : 집은 두 사람이 지내기에 아늑하고 따뜻했습니다. 에펠탑에서 매우 가까운 거리에 있었고, 집... → The house was cozy and warm for two people.It was ...
# ✅ [7/10] ko → en : 에펠탑이 도보 10분 내에 있어 매일 에펠탑으로 산책나갈 수 있었습니다.... → The Eiffel Tower was within a 10 -minute walk, so ...
# ✅ [8/10] ko → en : 에펠탑 근처이고, 1-2분 정도 걸으면 지하철 역 있어서 위치는 되게 좋아요. 집도 깔끔하... → It is near the Eiffel Tower, and if you walk for 1...
# ✅ [9/10] ko → en : 계단이 어마무시해서 힘들게 여행하고 숙소 올라가는게 더 힘들었고 , 배수구 물이 잘 안빠집... → The stairs were so hard that it was harder to trav...
# ✅ [10/10] ko → en : 위치가 아주 좋고, 호스트가 아주 친절합니다.... → The location is very good and the host is very fri...
#    ⏳ Batch 11/6 en cours...
# ✅ [1/10] ko → en : 개선문 도보 10분, 집 앞 도보 1분 버스정류장이 바로 있고, 에어프랑스 리무진 타고 공... → There is a 10 -minute walk from the Arc de Triomph...
# ✅ [2/10] ko → en : 에어비앤비를 처음 이용해보는 거라 걱정이 되었는데, 호스트가 친절해서 좋았어요! 체크인 할... → I was worried that I was using Airbnb for the firs...
# ✅ [3/10] ko → en : 너무나 만족합니다. 여행 기간 동안 편안하게 쉬었습니다.... → I'm so satisfied.I rested comfortably during my tr...
# ✅ [4/10] ko → en : 위치가 정말 멋지다. 4박 5일을 지냈는데, 4번의 밤마다 돌아오는 길에 에펠탑이 반짝이는... → The location is really cool.I spent four nights an...
# ✅ [5/10] ko → en : Fred는 매우 친절한 호스트 입니다. 소통에도 문제가 없었으며, 궁금한 질문들(주변 상점... → Fred is a very friendly host.There was no problem ...
# ✅ [6/10] ko → en : 집은 깔끔하고 수건도 많아서 좋았습니다. 식기류와 와인 따개 등 다양한 주방 용구들이 있었... → The house was clean and there were many towels.The...
# ✅ [7/10] ko → en : 에펠탑과 가깝고 한적한 동네라 좋았습니다.... → It was good because it was close to the Eiffel Tow...
# ✅ [8/10] ko → en : 距離公車與地鐵非常方便<br/>樓下即有超市<br/>附近的餐廳選擇也非常多樣<br/>廚房設備齊全... → 距 車 地 地 便 <br/> 下 下 有 有 也 也 也 常 樣 樣 <br/>...
# ✅ [9/10] ko → en : 在巴黎的位置位於15區，離地鐵很近，樓下就是超市非常便利。<br/>附近也有許多店家可以採買民生用品... → 在 的 的 15 地 地 鐵 很。 下 下 是 是 是。。。 <br/>有 有 不 不 ， 跟 房 ...
# ✅ [10/10] ko → en : 에펠탑까지 도보로 가능하고 바로 아래 큰 마트가 있어서 정말 편리합니다. 그냥 엘리베이터만... → The hotel is located in the heart of the city, clo...
#    ⏳ Batch 21/6 en cours...
# ✅ [1/10] ko → en : 집상태나 위치는 괜찮으나 환기가 잘 안됨. 또한 체크아웃시 침대포와 이불,베개 겉싸게를 다... → The state of the house and the location of the hou...
# ✅ [2/10] ko → en : 개인적으론 그냥그랬어요. 위생이나... 침대나... 접근성이나. ... → Personally, I just did it.Hygiene, ... bed or ... ...
# ✅ [3/10] ko → en : 위치가 좋고 호스트가 친절하고 답이 빨라서 좋았어요! 그리고 침대가 왕왕푹신해서 꿀잠잤어요... → It was good because the location was good, the hos...
# ✅ [4/10] ko → en : 위치 정말 좋아요. 공항에서 한번에오고 지하철 내려서도 엄청 가깝습니다.<br/>사진 과장... → The location is really good.It was very close to t...
# ✅ [5/10] ko → en : 역도가깝고 마트도 가까워서 좋았지만 좀 덥고 벌레가 많이 들어와서 밤마다 잡느라 혼났네요.... → It was good because it was close to the mart and t...
# ✅ [6/10] ko → en : 호스트의 인테리어 센스가 돋보이는 숙소에요. 사진으로 그 감성이 담기지 않네요. 멋진 공간... → It is a hostel with the interior sense of the host...
# ✅ [7/10] ko → en : 에펠탑 바로 앞에 있습니다 걸어서10-15 분 위치에 있구요 교통도 지하철역 오분?거리라 ... → It is located in front of the Eiffel Tower 10-15 m...
# ✅ [8/10] ko → en : 公寓附近十分熱鬧且便利，帶給我們旅途上不少的方便，離各大景點也都十分的近，只需步行十幾分鐘就能看到美... → 且 們 我 們 途 上 上 不少 的只 步 步 就 的 的 的 的 的 的。。 若 想 逛 的 的 ...
# ✅ [9/10] ko → en : 위치는 매우 좋았다. 집은 예상보다 작았지만 깔끔했다. 하지만 욕실이 생각보다 너무 작아서... → The location was very good.The house was smaller t...
# ✅ [10/10] ko → en : 숙소 전반적인 것에 대해서 설명도 잘 해주시고! 따로 여행안내서도 이메일로 보내주셔서 주변... → Please explain well about the overall accommodatio...
#    ⏳ Batch 31/6 en cours...
# ✅ [1/10] ko → en : 지내기에 부족한 것이 없었습니다. 주변에 대중교통고 많고요~ 호스트가 세심하게 많이 준비해... → There was nothing short of staying.There are many ...
# ✅ [2/10] ko → en : 정말 멋진 뷰 매일같이 아침 저녁으로 보는 에펠타워의 모습은 좋았으나. 샤워실문이 깨져있어... → The Eiffel Tower was really good every morning and...
# ✅ [3/10] ko → en : 일단 주인분들이 너무너무너무 친절하세요!! 집도 너무 이쁘고 앞에 베란다가 마당처럼 되있어... → First of all, the owners are so kind !!The house i...
# ✅ [4/10] ko → en : 정말 좋았습니다.<br/>위치도 너무 좋고 숙소 청결도나 시설도<br/>아주 좋았습니다!<... → It was really good. <br/> The location was so good...
# ✅ [5/10] ko → en : 조용하고 트렌디한 집이고 정말 편했습니다. 위치가 도심하고 좀 멀지만 움직이는데는 큰 문제... → It was a quiet and trendy house and it was really ...
# ✅ [6/10] ko → en : 5일 동안 지냈습니다.<br/>9라인 볼때흐 역과 가깝습니다. <br/>파리 북역에서는 매... → I've been spent 5 days.<br/> It takes about 30 min...
# ✅ [7/10] ko → en : 마크는 참 친절했고 우리가 숙소에서 어떻게 지내야 할지 잘 알려주었고 머물기에도 위치도 좋... → Mark was very friendly, and it was good to know ho...
# ✅ [8/10] ko → en : 숙소가 커서 아이들 둘과 지내기에 너무 좋았습니다. 다만, 샤워시설이 작아서 약간 불편하긴... → The hostel was so big that it was so good to stay ...
# ✅ [9/10] ko → en : 사진을 잘 못찍은거 같아요. 실제가 훨신 좋아요. 생각보다 더 좋고, 위치, 주변 편의시설... → I don't think I took a picture.I really like it.It...
# ✅ [10/10] ko → en : pauline네 집은 사진과 정말 똑같았다. 엄마와 둘이 3박을 이용하였는데, 3명이 지내... → Pauline your house was really the same as the pict...
#    ⏳ Batch 41/6 en cours...
# ✅ [1/10] ko → en : 한쿡인만알아보게쑬게요 방의청켤됴와뜨겨운물콰온도엔 문줴없었어요 괜찮었어요 하쥐만체쿠아윳할때방... → I'll only find out Han Cook.Oh Wat Hepis 뉭 뉭 뉭 Pra...
# ✅ [2/10] ko → en : 호스트는 친절합니다. 집은 넓고 좋습니다. 여러 지하철 역 사이에 있어 조금만 걸으면 어디... → The host is kind.The house is wide and good.You ca...
# ✅ [3/10] ko → en : 좋았습니다.... → Good....
# ✅ [4/10] ko → en : 交通便利, 房子空間也夠大只是舊了點, 木地板走起來有聲音, 晚上夜深人靜時會覺得吵. 其他都沒什麼... → 便 利, 房子 也 大 大 是 了, 木 地 板 起 有 聲 有, 晚 上 人 靜 會 吵.其 沒 ...
# ✅ [5/10] ko → en : 숙소 위치가 일단 7구 에펠탑에서15-20분 거리라 좋았어요! 근처에 박물관 미술관이 있고... → The location of the hostel was 15-20 minutes from ...
# ✅ [6/10] ko → en : 신혼여행으로 한달동안 지냈는데 불편한거 없이 좋았어요. 지하철역과도 가깝고, 파리가 작아서... → I spent a month on my honeymoon and it was good wi...
# ✅ [7/10] ko → en : 交通便利，到地鐵站&任何景點都很容易<br/>安靜又安全的美麗住宅區<br/>生活機能非常好<br/... → 地 利 地 地 易 容 容 易 易 容 容 宅 宅 宅 宅 宅 宅 <br/> 生活 能 好 好 好...
# ✅ [8/10] ko → en : 這個房子在便利安全的14區，走路五分鐘之內能抵達車站，非常方便。附近有家樂福以及許多咖啡廳餐廳，還有... → 這 子 子 在 安 安 的 的 14 之 之 之 內。。。。許 多 咖啡 餐 餐 有 有 有 有。。...
# ✅ [9/10] ko → en : 알레시아는 버스 연결이 편리하고 서울에 비하면 굉장히 가깝지만 파리로는 외곽이라 말할지도 ... → Alesia is convenient for bus connections and is ve...
# ✅ [10/10] ko → en : 사진과 같습니다.<br/>좋은위치에 있고 추천합니다.... → It is the same as the picture. <br/> It is recomme...
#    ⏳ Batch 51/6 en cours...
# ✅ [1/7] ko → en : 생 제르맹 프레 역에서 도보 5분 거리입니다. 주변에 초등학교가 있어서 낮에는 조금 시끄럽... → It's a 5 -minute walk from Saint -Germain Fre Stat...
# ✅ [2/7] ko → en : 그녀가 적어놓은 모든 항목이 다 맞아 떨어집니다. <br/>그러므로 최고의 숙소라고도 할 ... → All the items she wrote down are right.<br/> There...
# ✅ [3/7] ko → en : 걸어서 10분 거리에 4호선 지하철이 있는데 이걸 타면 파리 시내로 굉장히 쉽게 갈 수 있... → There is a subway on Line 4, 10 minutes away, and ...
# ✅ [4/7] ko → en : Celine 人非常好也非常友善，住家環境也非常安靜，而且也接近地鐵站，住家旁邊就有家樂福超商，出門... → Celine人 常 好 也 也 安 安 安靜 地 地 地 地 地 地 地 有 有 有 樂 有 有 有...
# ✅ [5/7] ko → en : 호스트님의<br/>친절한 설명과 섬세함이 너무 좋았습니다.<br/>주변에 레스토랑이 다 훌... → The host's <br/> The friendly explanation and deli...
# ✅ [6/7] ko → en : 에펠탑이 웅장하게 보이는 편안한 아파트였습이다. 아파트여서 압도적으로 넓고 캐리어를 펼 공... → The Eiffel Tower was a comfortable apartment.The a...
# ✅ [7/7] ko → en : 주변에 버스와 메트로가 있어 돌아다니기 편리하고 집주인분이 직접 숙소 체크인과 설명을 도와... → There are buses and metro around, making it conven...
#
# 🟢 Langue détectée : da - 15 phrases
#    ⏳ Batch 1/2 en cours...
# ✅ [1/10] da → en : The kindest host I've ever met.... → The Kindest Host I'm ever met....
# ✅ [2/10] da → en : Vi er en familie på 2 voksne og 3 børn og boede ho... → We are a family of 2 adults and 3 children and liv...
# ✅ [3/10] da → en : Sophie er den perfekte værtinde. Alt var lagt til ... → Sophie is the perfect hostess.Everything was set f...
# ✅ [4/10] da → en : Perfekt bolig i spændende og trygt område.... → Perfect housing in exciting and safe area....
# ✅ [5/10] da → en : Virkelig smagfuldt og personligt indrettet bolig. ... → Really tasteful and personally furnished housing.W...
# ✅ [6/10] da → en : Meget fin lejlighed , levede flot op til forventni... → Very nice apartment, lived up to expectations.Real...
# ✅ [7/10] da → en : Rachael and Fabians lejlighed er en god rummelig l... → Rachael and Fabian's apartment is a good spacious ...
# ✅ [8/10] da → en : Fin lejlighed med ok beliggenhed, en del af Paris ... → Nice apartment with ok location, part of Paris you...
# ✅ [9/10] da → en : I kan forvente en dejlig lejlighed i et område som... → You can expect a lovely apartment in an area such ...
# ✅ [10/10] da → en : Vi synes lejligheden var charmerende og funktionel... → We think the apartment was charming and functional...
#    ⏳ Batch 11/2 en cours...
# ✅ [1/5] da → en : Stedet var meget hyggeligt og passer meget godt ti... → The place was very cozy and fits very well for a c...
# ✅ [2/5] da → en : Virkelig lækkert sted og meget centralt i Marais k... → Really delicious place and very central in the Mar...
# ✅ [3/5] da → en : Super oplevelse... Dejlig lille lejlighed. Dejligt... → Super experience ... Lovely little apartment.Lovel...
# ✅ [4/5] da → en :  Meget vel udrustet, rar og hyggelig lejlighed i l... → Very well equipped, nice and cozy apartment in sma...
# ✅ [5/5] da → en : Rigtig fin modtagelse og beskrivelse af området om... → Really nice reception and description of the area ...
#
# 🟢 Langue détectée : ca - 11 phrases
#    ⏳ Batch 1/2 en cours...
# ✅ [1/10] ca → en : Cadre très agréable, très accueil.... → Très Agréable Code, Très Accueil....
# ✅ [2/10] ca → en : Merci beaucoup Lola !... → Merci Beaucoup Lola!...
# ✅ [3/10] ca → en : Excellent value! Great location.... → Excellent Value!Great Location....
# ✅ [4/10] ca → en : Très bon cadre 😊👌.... → Très good cadri 😊👌....
# ✅ [5/10] ca → en : Excellent... → Excellent...
# ✅ [6/10] ca → en : Excellent... → Excellent...
# ✅ [7/10] ca → en : Estudi olt ben situat, a prop de parada de metro y... → Study oak well located, near the metro stop and a ...
# ✅ [8/10] ca → en : excelent!!!!!... → Excellent !!!!!...
# ✅ [9/10] ca → en : Impeccable 👌... → Impeccably 👌...
# ✅ [10/10] ca → en : Un petit estudi molt ben situat a Pigalle. Sense l... → A small study very well located in Pigalle.Without...
#    ⏳ Batch 11/2 en cours...
# ✅ [1/1] ca → en : Excellent Airbnb... → Excellent Airbnb...
#
# 🟢 Langue détectée : so - 3 phrases
#    ⏳ Batch 1/1 en cours...
# ✅ [1/3] so → en : Good!... → Good!...
# ✅ [2/3] so → en : xx... → Xx...
# ✅ [3/3] so → en : was good... → WAST GOOD...
#
# 🟢 Langue détectée : id - 4 phrases
#    ⏳ Batch 1/1 en cours...
# ✅ [1/4] id → en : Thank you pascal!... → Thank you Pascal!...
# ✅ [2/4] id → en : Superbe!... → Superbe!...
# ✅ [3/4] id → en : J... → J...
# ✅ [4/4] id → en : Super... → Super...
#
# 🟢 Langue détectée : sv - 8 phrases
#    ⏳ Batch 1/1 en cours...
# ✅ [1/8] sv → en : Trevlig lägenhet med allt som behövs. Köket är väl... → Nice apartment with everything needed.The kitchen ...
# ✅ [2/8] sv → en : Vi hade en fantastisk vistelse och trivdes utmärkt... → We had a fantastic stay and enjoyed the apartment ...
# ✅ [3/8] sv → en : Vi trivdes bra i denna lägenhet - den överensstämd... → We enjoyed this apartment - it was well in line wi...
# ✅ [4/8] sv → en : Trevlig värd och fin lägenhet i flera etage med äl... → Nice host and nice apartment in several floors wit...
# ✅ [5/8] sv → en : Vi är väldigt nöjda med detta boende. Det är litet... → We are very pleased with this accommodation.It is ...
# ✅ [6/8] sv → en : Mysig lägenhet, trevligt område med autentisk kara... → Cozy apartment, nice area with authentic character...
# ✅ [7/8] sv → en : Julie var mycket flexibel när det gällde in- och u... → Julie was very flexible when it came to check-in a...
# ✅ [8/8] sv → en : Lägenheten var perfekt disponerad, smakfullt inred... → The apartment was perfectly disposed of, tastefull...
#
# 🟢 Langue détectée : hu - 1 phrases
#    ⏳ Batch 1/1 en cours...
# ✅ [1/1] hu → en : Apartment = amazing... → Apartment = Amazing...
#
# 🟢 Langue détectée : he - 2 phrases
#    ⏳ Batch 1/1 en cours...
# ✅ [1/2] he → en : המיקום מושלם, הדירה קטנה יותר ממה שנראה בתמונות, כ... → The location is perfect, the apartment is smaller ...
# ✅ [2/2] he → en : המיקום מעולה, קרוב להכול, מלה מסעדות בסביבה.<br/> ... → The location is excellent, close to all, a restaur...
#
# 🟢 Langue détectée : unknown - 6 phrases
#    ⏳ Batch 1/1 en cours...
# ✅ [1/6] auto → en : .... → ....
# ✅ [2/6] auto → en : 👍... → 👍...
# ✅ [3/6] auto → en : 👍🏻... → 👍🏻...
# ✅ [4/6] auto → en : .... → ....
# ✅ [5/6] auto → en : ´... → ´...
# ✅ [6/6] auto → en : ......... → .........
#
# 🟢 Langue détectée : af - 7 phrases
#    ⏳ Batch 1/1 en cours...
# ✅ [1/7] af → en : Very good... → Very good...
# ✅ [2/7] af → en : Just awesome... → Just awesome...
# ✅ [3/7] af → en : Very good... → Very good...
# ✅ [4/7] af → en : very good... → very good...
# ✅ [5/7] af → en : Very good host... → Very good host...
# ✅ [6/7] af → en : Very good ... → Very good...
# ✅ [7/7] af → en : Very good.... → Very good....
#
# 🟢 Langue détectée : el - 3 phrases
#    ⏳ Batch 1/1 en cours...
# ✅ [1/3] el → en : To διαμέρισμα της Marie Odile είναι εξαιρετικό. Οτ... → Marie Odile's apartment is excellent.The best one ...
# ✅ [2/3] el → en : Ήταν πολύ φιλόξενη και κατατοπιστική σε ότι και αν... → It was very welcoming and informative in whatever ...
# ✅ [3/3] el → en : Καθαρό σπίτι και φιλόξενοι οικοδεσπότες... → Clean house and hospitable hosts...
#
# 🟢 Langue détectée : pl - 5 phrases
#    ⏳ Batch 1/1 en cours...
# ✅ [1/5] pl → en : Mieszkanie zgodne z opisem, w bliskiej okolicy skl... → A flat in accordance with the description, shops a...
# ✅ [2/5] pl → en : Pobyt przebiegł bez żadnych problemów, bardzo dobr... → The stay went without any problems, very good cont...
# ✅ [3/5] pl → en : Mieszkanie Sophie jest dokładnie takie jak na załą... → The Sophie apartment is exactly like the photos at...
# ✅ [4/5] pl → en : Dziękujemy za wizytę. Spędziliśmy w mieszkaniu bar... → Thank you for your visit.We spent very nice moment...
# ✅ [5/5] pl → en : (English below) Szczerze polecamy pobyt w mieszkan... → (English Below) We sincerely recommend staying in ...
#
# 🟢 Langue détectée : vi - 1 phrases
#    ⏳ Batch 1/1 en cours...
# ✅ [1/1] vi → en : H... → H...
#
# 🟢 Langue détectée : et - 1 phrases
#    ⏳ Batch 1/1 en cours...
# ✅ [1/1] et → en : студия для романтиков. маленькая, но очень уютная,... → студия для романтиков.маленькая, но очень уютная, ...
#
# 🟢 Langue détectée : ro - 5 phrases
#    ⏳ Batch 1/1 en cours...
# ✅ [1/5] ro → en : just perfect!... → just perfect!...
# ✅ [2/5] ro → en : Amazing spot for a fantastic price.... → Amazing spot for a fantastic price....
# ✅ [3/5] ro → en : great!!!!... → Great !!!!...
# ✅ [4/5] ro → en : nice cozy apartment in a vibrant area... → Nice Cozy Apartment in a vibrant area...
# ✅ [5/5] ro → en : Great experience... → Great Experience...
#
# 🟢 Langue détectée : fi - 3 phrases
#    ⏳ Batch 1/1 en cours...
# ✅ [1/3] fi → en : Isabelle ja asuntonsa olivat aivan mahtavia! Tyyli... → Isabelle and their apartments were absolutely awes...
# ✅ [2/3] fi → en : Fantastinen huoneisto. Supernopeat hissit. Asunto ... → Fantastic apartment.Super -fast elevators.The apar...
# ✅ [3/3] fi → en : Hinta laatusuhde hyvä. Viihtyisä asunto. Näkymä ei... → Price quality ratio good.Cozy apartment.View of Ei...
#
# 🟢 Langue détectée : ja - 5 phrases
#    ⏳ Batch 1/1 en cours...
# ✅ [1/5] ja → en : パリのオペラ座のすぐ側。オペラ座は空港からのロワシーバスがあったり、複数の地下鉄が止まる駅であったり... → Right next to the Opera House in Paris.The Opera H...
# ✅ [2/5] ja → en : 清潔で設備の整った素晴らしいアパルトマンです！<br/>建物はオスマン様式ですが 綺麗にリフォームさ... → A wonderful, clean and well equipped apartment!<br...
# ✅ [3/5] ja → en : とても綺麗で広いアパートです<br/>安全で静かな地区... → Very clean and spacious apartment <br/>A safe and ...
# ✅ [4/5] ja → en : ２週間強、ノルマンディー＆ブルターニュをドライブ旅行の後にパリに６日間お世話になりました。... → After a drive trip around Normandy and Brittany fo...
# ✅ [5/5] ja → en : 商店街やバス通りから少し入ったところで、場所は大変便利です。<br/>パリに居ながら静かな庭でバカン... → The location is very convenient, just a short walk...
#
# 🟢 Langue détectée : cy - 1 phrases
#    ⏳ Batch 1/1 en cours...
# ✅ [1/1] cy → en : All good.... → All good....
#
# 🟢 Langue détectée : tl - 2 phrases
#    ⏳ Batch 1/1 en cours...
# ✅ [1/2] tl → en : Amazing!... → Amazing!...
# ✅ [2/2] tl → en : Had an amazing stay!... → Had an amazing stay!...

# %%
import pandas as pd



# Vérifier que les colonnes existent
if "description_translated" in merged_data.columns and "comments_translated" in merged_data.columns:

    # Trier le DataFrame par la colonne des descriptions pour regrouper les éléments similaires
    merged_data = merged_data.sort_values(by="description_translated").reset_index(drop=True)

    # Sauvegarder le fichier trié
    output_file = "merged_data_grouped_sorted.xlsx"
    merged_data.to_excel(output_file, index=False)

    print(f"📂 Fichier trié et regroupé visuellement enregistré sous : {output_file}")

    # Affichage des résultats
    from IPython.display import display
    # Afficher le DataFrame directement dans l'interface
    display(merged_data)

else:
    print("❌ Les colonnes 'description_translated' et 'comments_translated' sont introuvables dans le fichier.")
# Out:
# 📂 Fichier trié et regroupé visuellement enregistré sous : merged_data_grouped_sorted.xlsx
#       listing_id                                        description  \
# 0          93287  MODERN AND STYLISH APARTMENT, COMPLETE RENOVAT...
# 1          93287  MODERN AND STYLISH APARTMENT, COMPLETE RENOVAT...
# 2          93287  MODERN AND STYLISH APARTMENT, COMPLETE RENOVAT...
# 3          93287  MODERN AND STYLISH APARTMENT, COMPLETE RENOVAT...
# 4          93287  MODERN AND STYLISH APARTMENT, COMPLETE RENOVAT...
# ...          ...                                                ...
# 9992      167998  A local neighbourhood filled with history, res...
# 9993      167998  A local neighbourhood filled with history, res...
# 9994      167998  A local neighbourhood filled with history, res...
# 9995      167998  A local neighbourhood filled with history, res...
# 9996      568394  - In the heart of one of the oldest district o...
#
#                                                comments description_lang  \
# 0     A terrific location. \r<br/>Nice , clean and n...               so
# 1     The location and the facilities of the apartme...               so
# 2     We were so lucky to find this beautiful apartm...               so
# 3     Wonderful apartment in the heart of Paris - on...               so
# 4     Excellent location; just steps away from amazi...               so
# ...                                                 ...              ...
# 9992  Louise, our host was fabulous, friendly and he...               en
# 9993  Louise was a wonderful host and promptly showe...               en
# 9994  Louise的房子地点简直太赞了！街对面就是几家很小资开到很晚的餐馆和时尚服装店，走出街就是...               en
# 9995  Louise's flat is beautiful, chic and has a per...               en
# 9996      Perfect location! Cozy and chic apartment! A+               en
#
#      comments_lang                             description_translated  \
# 0               en  Modann and stylish apartment, complete Renovat...
# 1               en  Modann and stylish apartment, complete Renovat...
# 2               en  Modann and stylish apartment, complete Renovat...
# 3               en  Modann and stylish apartment, complete Renovat...
# 4               en  Modann and stylish apartment, complete Renovat...
# ...            ...                                                ...
# 9992            en                                                nan
# 9993            en                                                nan
# 9994         zh-cn                                                nan
# 9995            en                                                nan
# 9996            en                                                nan
#
#                                     comments_translated
# 0                                                   nan
# 1                                                   nan
# 2                                                   nan
# 3                                                   nan
# 4                                                   nan
# ...                                                 ...
# 9992                                                nan
# 9993                                                nan
# 9994  Superb apartment, very well placed to discover...
# 9995                                                nan
# 9996                                                nan
#
# [9997 rows x 7 columns]

# %%
print(merged_data['description_translated'])
# Out:
# 0       Modann and stylish apartment, complete Renovat...
# 1       Modann and stylish apartment, complete Renovat...
# 2       Modann and stylish apartment, complete Renovat...
# 3       Modann and stylish apartment, complete Renovat...
# 4       Modann and stylish apartment, complete Renovat...
#                               ...
# 9992                                                  nan
# 9993                                                  nan
# 9994                                                  nan
# 9995                                                  nan
# 9996                                                  nan
# Name: description_translated, Length: 9997, dtype: object

# %%
import pandas as pd
from IPython.display import display  # Pour affichage dans Jupyter/Colab

# Vérifier si les colonnes de traduction existent
if 'description_translated' in merged_data.columns and 'comments_translated' in merged_data.columns:

    # 🔹 Remplacer les traductions échouées (NaN ou contenant ❌) par la description originale
    merged_data['description_translated'] = merged_data.apply(
        lambda row: row['description'] if pd.isna(row['description_translated']) or "x" in str(row['description_translated'])
        else row['description_translated'],
        axis=1
    )

    # 🔹 Remplacer les traductions échouées (NaN) dans `comments_translated` par `comments`
    merged_data['comments_translated'] = merged_data.apply(
        lambda row: row['comments'] if pd.isna(row['comments_translated']) or "x" in str(row['comments_translated'])
        else row['comments_translated'],
        axis=1
    )

    print("✅ Les descriptions et commentaires non traduits ont été remplacés par leur version originale.")

    # 🔹 Affichage du DataFrame mis à jour
    display(merged_data)

    # 🔹 Sauvegarde dans un fichier Excel
    output_file = "merged_data_updated.xlsx"
    merged_data.to_excel(output_file, index=False)
    print(f"📂 Fichier sauvegardé sous : {output_file}")

else:
    print("x Les colonnes 'description_translated' ou 'comments_translated' sont introuvables.")
# Out:
# ✅ Les descriptions et commentaires non traduits ont été remplacés par leur version originale.
#       listing_id                                        description  \
# 0          93287  MODERN AND STYLISH APARTMENT, COMPLETE RENOVAT...
# 1          93287  MODERN AND STYLISH APARTMENT, COMPLETE RENOVAT...
# 2          93287  MODERN AND STYLISH APARTMENT, COMPLETE RENOVAT...
# 3          93287  MODERN AND STYLISH APARTMENT, COMPLETE RENOVAT...
# 4          93287  MODERN AND STYLISH APARTMENT, COMPLETE RENOVAT...
# ...          ...                                                ...
# 9992      167998  A local neighbourhood filled with history, res...
# 9993      167998  A local neighbourhood filled with history, res...
# 9994      167998  A local neighbourhood filled with history, res...
# 9995      167998  A local neighbourhood filled with history, res...
# 9996      568394  - In the heart of one of the oldest district o...
#
#                                                comments description_lang  \
# 0     A terrific location. \r<br/>Nice , clean and n...               so
# 1     The location and the facilities of the apartme...               so
# 2     We were so lucky to find this beautiful apartm...               so
# 3     Wonderful apartment in the heart of Paris - on...               so
# 4     Excellent location; just steps away from amazi...               so
# ...                                                 ...              ...
# 9992  Louise, our host was fabulous, friendly and he...               en
# 9993  Louise was a wonderful host and promptly showe...               en
# 9994  Louise的房子地点简直太赞了！街对面就是几家很小资开到很晚的餐馆和时尚服装店，走出街就是...               en
# 9995  Louise's flat is beautiful, chic and has a per...               en
# 9996      Perfect location! Cozy and chic apartment! A+               en
#
#      comments_lang                             description_translated  \
# 0               en  Modann and stylish apartment, complete Renovat...
# 1               en  Modann and stylish apartment, complete Renovat...
# 2               en  Modann and stylish apartment, complete Renovat...
# 3               en  Modann and stylish apartment, complete Renovat...
# 4               en  Modann and stylish apartment, complete Renovat...
# ...            ...                                                ...
# 9992            en                                                nan
# 9993            en                                                nan
# 9994         zh-cn                                                nan
# 9995            en                                                nan
# 9996            en                                                nan
#
#                                     comments_translated
# 0                                                   nan
# 1                                                   nan
# 2                                                   nan
# 3                                                   nan
# 4                                                   nan
# ...                                                 ...
# 9992                                                nan
# 9993                                                nan
# 9994  Superb apartment, very well placed to discover...
# 9995                                                nan
# 9996                                                nan
#
# [9997 rows x 7 columns]
# 📂 Fichier sauvegardé sous : merged_data_updated.xlsx

# %%
import pandas as pd
from IPython.display import display  # Pour affichage dans Jupyter/Colab

# Vérifier si les colonnes de traduction existent
if 'description_translated' in merged_data.columns and 'comments_translated' in merged_data.columns:

    # 🔹 Convertir en string pour éviter les erreurs
    merged_data['description_translated'] = merged_data['description_translated'].astype(str)
    merged_data['comments_translated'] = merged_data['comments_translated'].astype(str)

    # 🔹 Remplacer les descriptions non traduites par la version originale
    merged_data.loc[merged_data['description_translated'].isin(["nan", "NaN", "None", "", " "]), 'description_translated'] = merged_data['description']

    # 🔹 Remplacer les commentaires non traduits par la version originale
    merged_data.loc[merged_data['comments_translated'].isin(["nan", "NaN", "None", "", " "]), 'comments_translated'] = merged_data['comments']

    print("✅ Les descriptions et commentaires non traduits ont été correctement remplacés.")

    # 🔹 Affichage du DataFrame mis à jour
    display(merged_data)

    # 🔹 Sauvegarde dans un fichier Excel
    output_file = "merged_data_updated.xlsx"
    merged_data.to_excel(output_file, index=False)
    print(f"📂 Fichier sauvegardé sous : {output_file}")

else:
    print("❌ Les colonnes 'description_translated' ou 'comments_translated' sont introuvables.")
# Out:
# ✅ Les descriptions et commentaires non traduits ont été correctement remplacés.
#       listing_id                                        description  \
# 0          93287  MODERN AND STYLISH APARTMENT, COMPLETE RENOVAT...
# 1          93287  MODERN AND STYLISH APARTMENT, COMPLETE RENOVAT...
# 2          93287  MODERN AND STYLISH APARTMENT, COMPLETE RENOVAT...
# 3          93287  MODERN AND STYLISH APARTMENT, COMPLETE RENOVAT...
# 4          93287  MODERN AND STYLISH APARTMENT, COMPLETE RENOVAT...
# ...          ...                                                ...
# 9992      167998  A local neighbourhood filled with history, res...
# 9993      167998  A local neighbourhood filled with history, res...
# 9994      167998  A local neighbourhood filled with history, res...
# 9995      167998  A local neighbourhood filled with history, res...
# 9996      568394  - In the heart of one of the oldest district o...
#
#                                                comments description_lang  \
# 0     A terrific location. \r<br/>Nice , clean and n...               so
# 1     The location and the facilities of the apartme...               so
# 2     We were so lucky to find this beautiful apartm...               so
# 3     Wonderful apartment in the heart of Paris - on...               so
# 4     Excellent location; just steps away from amazi...               so
# ...                                                 ...              ...
# 9992  Louise, our host was fabulous, friendly and he...               en
# 9993  Louise was a wonderful host and promptly showe...               en
# 9994  Louise的房子地点简直太赞了！街对面就是几家很小资开到很晚的餐馆和时尚服装店，走出街就是...               en
# 9995  Louise's flat is beautiful, chic and has a per...               en
# 9996      Perfect location! Cozy and chic apartment! A+               en
#
#      comments_lang                             description_translated  \
# 0               en  Modann and stylish apartment, complete Renovat...
# 1               en  Modann and stylish apartment, complete Renovat...
# 2               en  Modann and stylish apartment, complete Renovat...
# 3               en  Modann and stylish apartment, complete Renovat...
# 4               en  Modann and stylish apartment, complete Renovat...
# ...            ...                                                ...
# 9992            en  A local neighbourhood filled with history, res...
# 9993            en  A local neighbourhood filled with history, res...
# 9994         zh-cn  A local neighbourhood filled with history, res...
# 9995            en  A local neighbourhood filled with history, res...
# 9996            en  - In the heart of one of the oldest district o...
#
#                                     comments_translated
# 0     A terrific location. \r<br/>Nice , clean and n...
# 1     The location and the facilities of the apartme...
# 2     We were so lucky to find this beautiful apartm...
# 3     Wonderful apartment in the heart of Paris - on...
# 4     Excellent location; just steps away from amazi...
# ...                                                 ...
# 9992  Louise, our host was fabulous, friendly and he...
# 9993  Louise was a wonderful host and promptly showe...
# 9994  Superb apartment, very well placed to discover...
# 9995  Louise's flat is beautiful, chic and has a per...
# 9996      Perfect location! Cozy and chic apartment! A+
#
# [9997 rows x 7 columns]
# 📂 Fichier sauvegardé sous : merged_data_updated.xlsx

# %%
# !pip install langdetect
# Out:
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from langdetect) (1.17.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993222 sha256=233d9084283b83ef71344585016ffc07e9c65bac054079bef5f6fdd5121ebce0
#   Stored in directory: /root/.cache/pip/wheels/0a/f2/b2/e5ca405801e05eb7c8ed5b3b4bcf1fcabcd6272c167640072e
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9

# %%
import pandas as pd
from langdetect import detect
from langdetect.lang_detect_exception import LangDetectException
from IPython.display import display  # Pour affichage dans Jupyter/Colab

# Fonction pour détecter la langue d'un texte (avec gestion des erreurs)
def detect_language(text):
    try:
        return detect(text) if pd.notna(text) and isinstance(text, str) else "unknown"
    except LangDetectException:
        return "unknown"

# 🔹 Appliquer la détection de langue sur les colonnes traduites
merged_data['description_translated_lang'] = merged_data['description_translated'].apply(detect_language)
merged_data['comments_translated_lang'] = merged_data['comments_translated'].apply(detect_language)

# 🔹 Filtrer pour ne garder que les traductions en anglais
merged_data = merged_data[(merged_data['description_translated_lang'] == "en") & (merged_data['comments_translated_lang'] == "en")].reset_index(drop=True)

print("✅ Seules les descriptions et commentaires traduits en anglais sont conservés.")

# 🔹 Affichage du DataFrame mis à jour
display(merged_data)

# 🔹 Sauvegarde dans un fichier Excel
output_file = "merged_data_english_only.xlsx"
merged_data.to_excel(output_file, index=False)
print(f"📂 Fichier sauvegardé sous : {output_file}")
# Out:
# ✅ Seules les descriptions et commentaires traduits en anglais sont conservés.
#       listing_id                                        description  \
# 0          93287  MODERN AND STYLISH APARTMENT, COMPLETE RENOVAT...
# 1          93287  MODERN AND STYLISH APARTMENT, COMPLETE RENOVAT...
# 2          93287  MODERN AND STYLISH APARTMENT, COMPLETE RENOVAT...
# 3          93287  MODERN AND STYLISH APARTMENT, COMPLETE RENOVAT...
# 4          93287  MODERN AND STYLISH APARTMENT, COMPLETE RENOVAT...
# ...          ...                                                ...
# 9053      167998  A local neighbourhood filled with history, res...
# 9054      167998  A local neighbourhood filled with history, res...
# 9055      167998  A local neighbourhood filled with history, res...
# 9056      167998  A local neighbourhood filled with history, res...
# 9057      568394  - In the heart of one of the oldest district o...
#
#                                                comments description_lang  \
# 0     A terrific location. \r<br/>Nice , clean and n...               so
# 1     The location and the facilities of the apartme...               so
# 2     We were so lucky to find this beautiful apartm...               so
# 3     Wonderful apartment in the heart of Paris - on...               so
# 4     Excellent location; just steps away from amazi...               so
# ...                                                 ...              ...
# 9053  Louise, our host was fabulous, friendly and he...               en
# 9054  Louise was a wonderful host and promptly showe...               en
# 9055  Louise的房子地点简直太赞了！街对面就是几家很小资开到很晚的餐馆和时尚服装店，走出街就是...               en
# 9056  Louise's flat is beautiful, chic and has a per...               en
# 9057      Perfect location! Cozy and chic apartment! A+               en
#
#      comments_lang                             description_translated  \
# 0               en  Modann and stylish apartment, complete Renovat...
# 1               en  Modann and stylish apartment, complete Renovat...
# 2               en  Modann and stylish apartment, complete Renovat...
# 3               en  Modann and stylish apartment, complete Renovat...
# 4               en  Modann and stylish apartment, complete Renovat...
# ...            ...                                                ...
# 9053            en  A local neighbourhood filled with history, res...
# 9054            en  A local neighbourhood filled with history, res...
# 9055         zh-cn  A local neighbourhood filled with history, res...
# 9056            en  A local neighbourhood filled with history, res...
# 9057            en  - In the heart of one of the oldest district o...
#
#                                     comments_translated  \
# 0     A terrific location. \r<br/>Nice , clean and n...
# 1     The location and the facilities of the apartme...
# 2     We were so lucky to find this beautiful apartm...
# 3     Wonderful apartment in the heart of Paris - on...
# 4     Excellent location; just steps away from amazi...
# ...                                                 ...
# 9053  Louise, our host was fabulous, friendly and he...
# 9054  Louise was a wonderful host and promptly showe...
# 9055  Superb apartment, very well placed to discover...
# 9056  Louise's flat is beautiful, chic and has a per...
# 9057      Perfect location! Cozy and chic apartment! A+
#
#      description_translated_lang comments_translated_lang
# 0                             en                       en
# 1                             en                       en
# 2                             en                       en
# 3                             en                       en
# 4                             en                       en
# ...                          ...                      ...
# 9053                          en                       en
# 9054                          en                       en
# 9055                          en                       en
# 9056                          en                       en
# 9057                          en                       en
#
# [9058 rows x 9 columns]
# 📂 Fichier sauvegardé sous : merged_data_english_only.xlsx

# %% [markdown]
# **j'ai enregistré la data pour l utiliser après dans le notebook Annotation+ pretraitement des donnée+ cosine similarity**
